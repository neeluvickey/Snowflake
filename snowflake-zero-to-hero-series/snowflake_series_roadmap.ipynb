# %% [markdown]
# # The Ultimate Snowflake Series — From Zero to Hero
#
# ### Welcome!
#
# Whether you're just getting started with Snowflake or looking to sharpen your skills, this series has you covered. We'll walk through **everything** Snowflake — concept by concept, with **deep dives** to build your knowledge, **hands-on exercises** you can try yourself, and **surprise interactive posts** along the way to keep things fun!
#
# No fluff. Just real, practical Snowflake learning.
#
# ---
#
# ### What to Expect
#
# | Format | What It Is |
# |--------|------------|
# | **Deep Dive** | Detailed breakdowns of Snowflake features with real-world context |
# | **Hands-On** | Guided exercises with SQL you can run in your own Snowflake account |
# | **Surprise!** | Interactive posts that pop up between topics — stay tuned! |
#
# ### Posting Schedule
# **3x per week** (Mon · Wed · Fri) — follow along and never miss a post!

# %% [markdown]
# ---
# ## PHASE 1 — Snowflake Foundations
# *Start here. Understand what Snowflake is, how it's built, and why it's different.*
#
# | # | What You'll Learn | Format |
# |---|-------------------|--------|
# | 1 | What is Snowflake? — The Cloud Data Platform explained simply | Deep Dive |
# | 2 | Snowflake's 3-Layer Architecture — Storage, Compute & Cloud Services | Deep Dive |
# | 3 | Snowflake Editions — Standard vs Enterprise vs Business Critical | Deep Dive |
# | 4 | How Snowflake Organizes Data — Databases & the Catalog | Deep Dive |
# | 5 | Schemas & the Information Schema — Your metadata toolkit | Deep Dive |
# | 6 | **Try It Yourself:** Create a database, schema & explore metadata | Hands-On |
# | 7 | How Snowflake Pricing Works — Credits, Storage & Costs | Deep Dive |

# %% [markdown]
# ---
# ## PHASE 2 — Virtual Warehouses & Compute
# *The engine behind every query. Learn how to size, scale, and save.*
#
# | # | What You'll Learn | Format |
# |---|-------------------|--------|
# | 8 | Virtual Warehouses — What they are and how they work | Deep Dive |
# | 9 | Scaling Policies — Standard vs Economy mode | Deep Dive |
# | 10 | Multi-Cluster Warehouses — Auto-scaling for concurrency | Deep Dive |
# | 11 | Resource Monitors — Put guardrails on your Snowflake spend | Deep Dive |
# | 12 | Warehouse Best Practices — Right-sizing, suspend & resume | Deep Dive |
# | 13 | **Try It Yourself:** Create, resize & monitor warehouses | Hands-On |

# %% [markdown]
# ---
# ## PHASE 3 — Tables & Data Types
# *From permanent tables to Iceberg — know every table type and when to use it.*
#
# | # | What You'll Learn | Format |
# |---|-------------------|--------|
# | 14 | Table Types — Permanent, Transient & Temporary | Deep Dive |
# | 15 | Snowflake Data Types — VARIANT, ARRAY, OBJECT & more | Deep Dive |
# | 16 | Working with Semi-Structured Data (JSON, Parquet, Avro) | Deep Dive |
# | 17 | **Try It Yourself:** Load & query JSON data in Snowflake | Hands-On |
# | 18 | External Tables — Query your data lake directly | Deep Dive |
# | 19 | Iceberg Tables — Open table formats in Snowflake | Deep Dive |
# | 20 | Dynamic Tables — Build pipelines declaratively | Deep Dive |
# | 21 | **Try It Yourself:** Build a data pipeline with Dynamic Tables | Hands-On |

# %% [markdown]
# ---
# ## PHASE 4 — Views & Data Access
# *Standard, materialized, secure — pick the right view for the job.*
#
# | # | What You'll Learn | Format |
# |---|-------------------|--------|
# | 22 | Views in Snowflake — Standard vs Materialized vs Secure | Deep Dive |
# | 23 | Materialized Views — Pre-computed results for speed | Deep Dive |
# | 24 | **Try It Yourself:** Create & compare view types + performance | Hands-On |
# | 25 | Sharing Data Safely with Secure Views | Deep Dive |
# | 26 | Semantic Views — Business-friendly data models | Deep Dive |

# %% [markdown]
# ---
# ## PHASE 5 — Stages & Data Loading
# *Get data in. Every method, every format, explained.*
#
# | # | What You'll Learn | Format |
# |---|-------------------|--------|
# | 27 | Stages — Internal vs External, and when to use each | Deep Dive |
# | 28 | COPY INTO — The workhorse of bulk data loading | Deep Dive |
# | 29 | Snowpipe — Continuous, event-driven data ingestion | Deep Dive |
# | 30 | Snowpipe Streaming — Near real-time ingestion | Deep Dive |
# | 31 | **Try It Yourself:** Load data using stages & COPY INTO | Hands-On |
# | 32 | File Formats — CSV, JSON, Parquet, Avro & ORC | Deep Dive |
# | 33 | PUT & GET — Moving files between local and Snowflake | Deep Dive |

# %% [markdown]
# ---
# ## PHASE 6 — Time Travel & Data Protection
# *Accidentally deleted something? Snowflake has your back.*
#
# | # | What You'll Learn | Format |
# |---|-------------------|--------|
# | 34 | Time Travel — Query data as it existed in the past | Deep Dive |
# | 35 | Fail-safe — Snowflake's last line of defense | Deep Dive |
# | 36 | UNDROP — Bring back dropped tables, schemas & databases | Deep Dive |
# | 37 | **Try It Yourself:** Time Travel & UNDROP in action | Hands-On |
# | 38 | Zero-Copy Cloning — Duplicate objects instantly, no extra storage | Deep Dive |
# | 39 | Cloning Best Practices — Dev, test & migration use cases | Deep Dive |

# %% [markdown]
# ---
# ## PHASE 7 — Security & Access Control
# *Lock it down. Roles, policies, encryption — enterprise-grade security.*
#
# | # | What You'll Learn | Format |
# |---|-------------------|--------|
# | 40 | Snowflake Security — Defense in depth overview | Deep Dive |
# | 41 | RBAC — Role-based access control & role hierarchy | Deep Dive |
# | 42 | System Roles — ACCOUNTADMIN, SYSADMIN & friends | Deep Dive |
# | 43 | **Try It Yourself:** Set up roles, grants & privileges | Hands-On |
# | 44 | Network Policies & IP Allowlisting | Deep Dive |
# | 45 | Dynamic Data Masking — Column-level security | Deep Dive |
# | 46 | Row Access Policies — Row-level security | Deep Dive |
# | 47 | **Try It Yourself:** Implement masking & row access policies | Hands-On |

# %% [markdown]
# ---
# ## PHASE 8 — Streams & Tasks (Change Data Capture)
# *Build real-time pipelines entirely inside Snowflake.*
#
# | # | What You'll Learn | Format |
# |---|-------------------|--------|
# | 48 | Streams — Capture every change on your tables | Deep Dive |
# | 49 | Stream Types — Standard, Append-only & Insert-only | Deep Dive |
# | 50 | Tasks — Schedule SQL & stored procedures | Deep Dive |
# | 51 | Task Trees & DAGs — Orchestrate multi-step workflows | Deep Dive |
# | 52 | Serverless Tasks — Run without a warehouse | Deep Dive |
# | 53 | **Try It Yourself:** Build a CDC pipeline with Streams & Tasks | Hands-On |

# %% [markdown]
# ---
# ## PHASE 9 — Stored Procedures, UDFs & Snowpark
# *Extend Snowflake with code — SQL, Python, JavaScript & more.*
#
# | # | What You'll Learn | Format |
# |---|-------------------|--------|
# | 54 | Stored Procedures — Reusable logic in SQL & JavaScript | Deep Dive |
# | 55 | UDFs — Write custom functions in SQL, Python or JavaScript | Deep Dive |
# | 56 | UDTFs — Generate rows with table functions | Deep Dive |
# | 57 | Snowpark — The DataFrame API for Snowflake | Deep Dive |
# | 58 | Snowpark Python — Build pipelines without leaving Python | Deep Dive |
# | 59 | **Try It Yourself:** Build a data pipeline with Snowpark Python | Hands-On |
# | 60 | External Functions & API Integrations | Deep Dive |
# | 61 | Snowflake Scripting — Procedural SQL logic | Deep Dive |

# %% [markdown]
# ---
# ## PHASE 10 — Data Sharing & Collaboration
# *Share data across orgs without copying a single byte.*
#
# | # | What You'll Learn | Format |
# |---|-------------------|--------|
# | 62 | Secure Data Sharing — Zero-copy sharing explained | Deep Dive |
# | 63 | Snowflake Marketplace — Discover & publish data | Deep Dive |
# | 64 | Reader Accounts — Share with non-Snowflake users | Deep Dive |
# | 65 | Data Clean Rooms — Collaborate without exposing raw data | Deep Dive |
# | 66 | Cross-Cloud & Cross-Region Replication | Deep Dive |
# | 67 | **Try It Yourself:** Set up a data share & listing | Hands-On |

# %% [markdown]
# ---
# ## PHASE 11 — Performance Optimization
# *Make every query faster. Understand what Snowflake does under the hood.*
#
# | # | What You'll Learn | Format |
# |---|-------------------|--------|
# | 68 | Query Profile — Read execution plans like a pro | Deep Dive |
# | 69 | Micro-Partitions & Clustering Keys — How Snowflake stores data | Deep Dive |
# | 70 | Search Optimization Service — Speed up point lookups | Deep Dive |
# | 71 | Caching in Snowflake — Metadata, query result & warehouse cache | Deep Dive |
# | 72 | **Try It Yourself:** Query optimization — before & after | Hands-On |
# | 73 | Top 10 Snowflake Performance Best Practices | Deep Dive |

# %% [markdown]
# ---
# ## PHASE 12 — Snowflake Cortex & AI/ML
# *AI built into your data platform. No separate tools needed.*
#
# | # | What You'll Learn | Format |
# |---|-------------------|--------|
# | 74 | Snowflake Cortex — AI capabilities overview | Deep Dive |
# | 75 | Cortex LLM Functions — COMPLETE, SUMMARIZE, TRANSLATE & more | Deep Dive |
# | 76 | Cortex Analyst — Ask questions in plain English, get SQL | Deep Dive |
# | 77 | Cortex Search — AI-powered search over your data | Deep Dive |
# | 78 | Snowflake ML — Train models & use the Model Registry | Deep Dive |
# | 79 | **Try It Yourself:** Text analytics with Cortex LLM functions | Hands-On |
# | 80 | Feature Store & ML Pipelines in Snowflake | Deep Dive |
# | 81 | Snowflake Notebooks — Interactive development environment | Deep Dive |

# %% [markdown]
# ---
# ## PHASE 13 — Governance & Compliance
# *Classify, tag, audit, and protect your data at scale.*
#
# | # | What You'll Learn | Format |
# |---|-------------------|--------|
# | 82 | Data Governance in Snowflake — Horizon Catalog overview | Deep Dive |
# | 83 | Tags & Auto-Classification — Find sensitive data automatically | Deep Dive |
# | 84 | Access History & Query History — Full audit trail | Deep Dive |
# | 85 | Data Quality — Data Metric Functions (DMFs) | Deep Dive |
# | 86 | Lineage & Impact Analysis — Trace data end to end | Deep Dive |
# | 87 | **Try It Yourself:** Set up tags, classification & lineage | Hands-On |

# %% [markdown]
# ---
# ## PHASE 14 — Ecosystem & Integrations
# *Snowflake doesn't live alone. See how it connects to everything.*
#
# | # | What You'll Learn | Format |
# |---|-------------------|--------|
# | 88 | dbt + Snowflake — Modern SQL-based transformations | Deep Dive |
# | 89 | Streamlit in Snowflake — Build data apps with Python | Deep Dive |
# | 90 | **Try It Yourself:** Build a Streamlit dashboard in Snowflake | Hands-On |
# | 91 | Git Integration — Version control inside Snowflake | Deep Dive |
# | 92 | Snowflake CLI & SnowSQL — Command-line power tools | Deep Dive |
# | 93 | Native Apps Framework — Package & distribute applications | Deep Dive |

# %% [markdown]
# ---
# ## PHASE 15 — Advanced Topics & Series Finale
# *Level up. Certifications, cost strategies, interviews & a capstone project.*
#
# | # | What You'll Learn | Format |
# |---|-------------------|--------|
# | 94 | Snowflake Cost Optimization — Proven strategies | Deep Dive |
# | 95 | SnowPro Certifications — Which one is right for you? | Deep Dive |
# | 96 | Snowflake vs Databricks vs BigQuery vs Redshift | Deep Dive |
# | 97 | What's New in Snowflake — 2026 features & roadmap | Deep Dive |
# | 98 | **Capstone:** End-to-end project — Ingest, transform, analyze & visualize | Hands-On |
# | 99 | Top 20 Snowflake Interview Questions (with answers) | Deep Dive |
# | 100 | Series Wrap-Up — Key takeaways & what's next | Deep Dive |

# %% [markdown]
# ---
#
# ## Quick Stats
#
# | | Count |
# |---|-------|
# | Deep Dive Posts | 83 |
# | Hands-On Exercises | 16 |
# | Capstone Project | 1 |
# | **Total Posts** | **100** |
#
# *Plus surprise interactive posts sprinkled throughout — stay tuned!*
#
# ---
#
# ### How to Follow Along
# - **New here?** Start from Phase 1 and go in order — each phase builds on the last
# - **Already know the basics?** Jump to any phase that interests you
# - **Want to practice?** Look for the **Hands-On** posts — they include SQL you can run yourself
# - **Like surprises?** Keep an eye out for interactive posts between topics!
#
# ### New posts every **Monday, Wednesday & Friday**
#
# Drop a comment, share your experience, and let's learn Snowflake together!
